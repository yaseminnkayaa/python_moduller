# %%
import matplotlib.pyplot as plt
import seaborn as sns 
import numpy as np

# %%
dizi_1= np.random.randint(20,80,5)
dizi_2= np.random.randint(20,80,5)
uzunluk= np.arange(dizi_1.shape[0])

plt.plot(dizi_1,label="Dizi 1")
plt.plot(dizi_2,label="Dizi 2")
plt.xlabel("dönem bilgisi")
plt.xlabel("not bilgisi")
plt.title("dönemlere göre notlar")
plt.legend()
plt.xticks(uzunluk,["Deger 1","Deger 2","Deger 3","Deger 4","Deger 5"])
plt.show()

# %%
dizi_1= np.random.randint(20,80,5)
dizi_2= np.random.randint(20,80,5)
uzunluk= np.arange(dizi_1.shape[0])

plt.plot(dizi_1,label="Dizi 1")
plt.plot(dizi_2,label="Dizi 2")
plt.xlabel("dönem bilgisi")
plt.xlabel("not bilgisi")
plt.title("dönemlere göre notlar")
plt.legend()
plt.xticks(uzunluk,["Deger 1","Deger 2","Deger 3","Deger 4","Deger 5"])
plt.show()

# %%
dizi_1= np.random.randint(20,80,5)
dizi_2= np.random.randint(20,80,5)
uzunluk= np.arange(dizi_1.shape[0])

plt.plot(dizi_1,label="Dizi 1")
plt.plot(dizi_2,label="Dizi 2")
plt.xlabel("dönem bilgisi")
plt.xlabel("not bilgisi")
plt.title("dönemlere göre notlar")
plt.legend()
plt.xticks(uzunluk,["Deger 1","Deger 2","Deger 3","Deger 4","Deger 5"])
plt.show()

# %%
dizi_1= np.random.randint(20,80,5)
dizi_2= np.random.randint(20,80,5)
uzunluk= np.arange(dizi_1.shape[0])

plt.plot(dizi_1,label="Dizi 1")
plt.plot(dizi_2,label="Dizi 2")
plt.xlabel("dönem bilgisi")
plt.xlabel("not bilgisi")
plt.title("dönemlere göre notlar")
plt.legend()
plt.xticks(uzunluk,["Deger 1","Deger 2","Deger 3","Deger 4","Deger 5"])
plt.show()

# %%
kripto_1= np.random.randint(1000,50000,12)
kripto_2= np.random.randint(1000,50000,12)
uzunluk= np.arange(kripto_1.shape[0])

plt.plot(kripto_1,linestyle="--",color="blue",label="kripto 1")
plt.plot(kripto_2,linestyle="-.",color="red",label="kripto 2")
plt.xlabel("aylar")
plt.xlabel("fiyat/tl")
plt.title("2024 yılı kripto para fiyatları")
plt.legend()
plt.xticks(uzunluk,["ocak","şubat","mart","nisan","mayıs","haziran","temmuz","ağustos","eylül","ekim","kasım","aralık"],rotation=45)
plt.show()

# %%
#12 aylık bir borsa verisini temsil eden grafiği oluşturun
kripto_1= np.random.randint(1000,50000,12)
kripto_2= np.random.randint(1000,50000,12)
uzunluk= np.arange(kripto_1.shape[0])

plt.plot(kripto_1,linestyle="--",color="blue",label="kripto 1")
plt.plot(kripto_2,linestyle="-.",color="red",label="kripto 2")
plt.xlabel("aylar")
plt.xlabel("fiyat/tl")
plt.title("2024 yılı kripto para fiyatları")
plt.legend()
plt.xticks(uzunluk,["ocak","şubat","mart","nisan","mayıs","haziran","temmuz","ağustos","eylül","ekim","kasım","aralık"],rotation=45)
plt.savefig("env_ybs_3-1.png",dpi=500,bbox_inches="tight")
plt.show()

# %%
#bar(çubuk) grafikleri
kripto_1= np.random.randint(100,250,5)
kripto_2= np.random.randint(100,250,5)
uzunluk= np.arange(kripto_1.shape[0])

plt.plot(kripto_1,linestyle="--",color="blue",label="kripto 1")
plt.plot(kripto_2,linestyle="-.",color="red",label="kripto 2")

# %%
#bar(çubuk) grafikleri-1.gösterim:yan yana yazarak gösterme

fiyat_btc = np.random.randint(100,250,5)
fiyat_eth = np.random.randint(100,250,5)

uzunluk = np.arange(fiyat_btc.shape[0])

plt.bar(uzunluk,fiyat_btc,label="BTC")
plt.bar(uzunluk,fiyat_eth,label="ETH")
plt.xticks(uzunluk,["2020","2021","2022","2023","2024"])
plt.legend()
plt.show()

# %%
#bar(çubuk) grafikleri-1.gösterim:yan yana yazarak gösterme

fiyat_btc = np.random.randint(100,250,5)
fiyat_eth = np.random.randint(100,250,5)

dizi_isim = ["Bitcoin","Ethereum"]

ort_btc = np.mean(fiyat_btc)
ort_eth = np.mean(fiyat_eth)

new_dizi = [ort_btc,ort_eth]

plt.bar(dizi_isim,new_dizi,color=["orange","green"],label=["BTC","ETH"])

plt.legend()
plt.show()

# %%
#bar(çubuk) grafikleri-1.gösterim:yan yana yazarak gösterme

fiyat_btc = np.random.randint(100,250,5)
fiyat_eth = np.random.randint(100,250,5)

dizi_isim = ["Bitcoin","Ethereum"]

ort_btc = np.mean(fiyat_btc)
ort_eth = np.mean(fiyat_eth)

new_dizi = [ort_btc,ort_eth]

plt.bar(dizi_isim,new_dizi,color=["orange","green"],label=["BTC","ETH"])

plt.legend()
plt.show()

for i in range(len(dizi_isim)):
    plt.text(i,new_dizi[i],f"{new_dizi[i]:.2f}",ha="center",va="bottom")
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\envs\env_ybs_3\lib\site-packages\IPython\core\formatters.py:343, in BaseFormatter.__call__(self, obj)
#     341     pass
#     342 else:
# --> 343     return printer(obj)
#     344 # Finally look for special method names
#     345 method = get_real_method(obj, self.print_method)
#
# File ~\anaconda3\envs\env_ybs_3\lib\site-packages\IPython\core\pylabtools.py:170, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     167     from matplotlib.backend_bases import FigureCanvasBase
#     168     FigureCanvasBase(fig)
# --> 170 fig.canvas.print_figure(bytes_io, **kw)
#     171 data = bytes_io.getvalue()
#     172 if fmt == 'svg':
#
# ...

# %%
giderler=[180,550,350,130,290]
etiketler=["Muhasebe","Ar-Ge","İnsan Kaynakları","Kalite Yönetimi","Bilişim Teknolojileri"]
plt.pie(giderler,labels=etiketler)
plt.show()

# %%
giderler=[180,550,350,130,290]
etiketler=["Muhasebe","Ar-Ge","İnsan Kaynakları","Kalite Yönetimi","Bilişim Teknolojileri"]
ayirt_etme=[0,0,0.2,0,0]
##ingilizce yüzde gösterimi için autopct=1.1f%%
##türkçe yüzde gösterimi için autopct=%%%.1f
plt.pie(giderler,labels=etiketler,autopct="%%%.1f",shadow=True ,
       explode=ayirt_etme)
plt.show()

# %%
#scatter plot(kümeleme için)
#hazır penguins veri setinin yüklenmesi


data=sns.load_dataset("penguins")
data.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.scatterplot(x="bill_length_mm",y="bill_depth_mm",data=data,
                hue="species")
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %% [markdown]
# #outlier

# %%
sns.histplot(x="flipper_length_mm",data=data)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.histplot(x="flipper_length_mm",data=data,kde=True)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>
